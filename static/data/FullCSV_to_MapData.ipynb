# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(('/Users/benjaminmason/Desktop/Study/Project 03_Team 2/0_SS/Resourcse/Dataset.csv'), low_memory=False)
df.head()
# Out:
#            B_HashedKey                         B_FullName B_ShortName  \
# 0  3292694929379159574  1 Thynne Street, Bruce, ACT, 2617         NaN
# 1  3292694929379159574  1 Thynne Street, Bruce, ACT, 2617         NaN
# 2  3292694929379159574  1 Thynne Street, Bruce, ACT, 2617         NaN
# 3  3292694929379159574  1 Thynne Street, Bruce, ACT, 2617         NaN
# 4  3292694929379159574  1 Thynne Street, Bruce, ACT, 2617         NaN
#
#    B_StreetAddress B_Suburb  B_PostCode B_State       B_Geocode  B_Longitude  \
# 0  1 Thynne Street    Bruce        2617     ACT  GAACT714853532   149.093585
# 1  1 Thynne Street    Bruce        2617     ACT  GAACT714853532   149.093585
# 2  1 Thynne Street    Bruce        2617     ACT  GAACT714853532   149.093585
# 3  1 Thynne Street    Bruce        2617     ACT  GAACT714853532   149.093585
# 4  1 Thynne Street    Bruce        2617     ACT  GAACT714853532   149.093585
#
#    B_Latitude  ...  FS_ProposedNLPD FS_UTC_ProposedCompletionDate  \
# 0  -35.240431  ...              NaN                           NaN
# 1  -35.240431  ...              NaN                           NaN
# 2  -35.240431  ...              NaN                           NaN
# 3  -35.240431  ...              NaN                           NaN
# 4  -35.240431  ...              NaN                           NaN
#
#   FS_LOCAL_ProposedCompletionDate FS_ProposedReasonForAssessment  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#   FS_ProposedControlCapacity FS_CurrentNLPD FS_CurrentControlCapacity  \
# 0                        NaN            6.4                      Good
# 1                        NaN            6.4                      Good
# 2                        NaN            5.5                  Moderate
# 3                        NaN            5.5                  Moderate
# 4                        NaN            6.0                  Moderate
#
#   FS_PerformanceComment CRT_BuildingNla CRT_NumberOfLevels
# 0                   NaN          5848.0                3.0
# 1                   NaN          5848.0                3.0
# 2                   NaN          5848.0                3.0
# 3                   NaN          5848.0                3.0
# 4                   NaN          5848.0                3.0
#
# [5 rows x 62 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204749 entries, 0 to 204748
# Data columns (total 62 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   B_HashedKey                         204749 non-null  int64
#  1   B_FullName                          204749 non-null  object
#  2   B_ShortName                         142420 non-null  object
#  3   B_StreetAddress                     204749 non-null  object
#  4   B_Suburb                            204749 non-null  object
#  5   B_PostCode                          204749 non-null  int64
#  6   B_State                             204749 non-null  object
#  7   B_Geocode                           202042 non-null  object
#  8   B_Longitude                         196305 non-null  float64
#  9   B_Latitude                          196305 non-null  float64
#  10  CRT_HashedKey                       204749 non-null  int64
#  11  CRT_Name                            204749 non-null  object
#  12  CRT_AssessorName                    204749 non-null  object
#  13  CRT_CertificateNumber               202014 non-null  object
#  14  CRT_UTC_IssueDate                   201978 non-null  object
#  15  CRT_LOCAL_IssueDate                 201978 non-null  object
#  16  CRT_UTC_CurrentTo                   201978 non-null  object
#  17  CRT_LOCAL_CurrentTo                 201978 non-null  object
#  18  CRT_Scope                           61940 non-null   object
#  19  CRT_Purpose                         177333 non-null  object
#  20  CRT_UTC_SubmissionDate              177333 non-null  object
#  21  CRT_LOCAL_SubmissionDate            177333 non-null  object
#  22  CRT_Comment                         7001 non-null    object
#  23  CRT_Nabers_ReferenceNumber          204749 non-null  object
#  24  CRT_Nabers_StarRating               204749 non-null  float64
#  25  CRT_Nabers_RatedArea                204749 non-null  float64
#  26  CRT_Nabers_RatedHours               204749 non-null  float64
#  27  CRT_Nabers_RatingScope              204749 non-null  object
#  28  CRT_Nabers_CertifiedDate            204749 non-null  object
#  29  CRT_LOCAL_Nabers_CertifiedDate      204749 non-null  object
#  30  CRT_Nabers_CurrentTo                204749 non-null  object
#  31  CRT_LOCAL_Nabers_CurrentTo          204749 non-null  object
#  32  CRT_Nabers_AnnualEmissions          204749 non-null  float64
#  33  CRT_Nabers_AnnualEmissionIntensity  204749 non-null  float64
#  34  CRT_Nabers_AnnualConsumption        204749 non-null  float64
#  35  CRT_Nabers_OwnerName                204749 non-null  object
#  36  TLA_HashedKey                       204749 non-null  int64
#  37  TLA_Name                            204749 non-null  object
#  38  TLA_AssessorName                    204749 non-null  object
#  39  TLA_UTC_SubmittedDate               204749 non-null  object
#  40  TLA_LOCAL_SubmittedDate             204749 non-null  object
#  41  TLA_Number                          204349 non-null  object
#  42  TLA_Status                          204749 non-null  int64
#  43  TLA_NetLettableSpace                204749 non-null  float64
#  44  TLA_CertifiedDate                   204349 non-null  object
#  45  TLA_LOCAL_CertifiedDate             204349 non-null  object
#  46  TLA_CertificateExpiry               204349 non-null  object
#  47  TLA_AssessmentScope                 204749 non-null  object
#  48  FS_HashedKey                        204749 non-null  int64
#  49  FS_Name                             204744 non-null  object
#  50  FS_Level                            204744 non-null  float64
#  51  FS_NLA                              204740 non-null  float64
#  52  FS_ProposedNLPD                     343 non-null     float64
#  53  FS_UTC_ProposedCompletionDate       342 non-null     object
#  54  FS_LOCAL_ProposedCompletionDate     342 non-null     object
#  55  FS_ProposedReasonForAssessment      343 non-null     object
#  56  FS_ProposedControlCapacity          343 non-null     object
#  57  FS_CurrentNLPD                      183586 non-null  float64
#  58  FS_CurrentControlCapacity           185260 non-null  object
#  59  FS_PerformanceComment               36306 non-null   object
#  60  CRT_BuildingNla                     142807 non-null  float64
#  61  CRT_NumberOfLevels                  142807 non-null  float64
# dtypes: float64(15), int64(6), object(41)
# memory usage: 96.9+ MB

# %%
#Filter out columns that are not needed for charting / mapping amd create new DF 
Map_data = df.drop(columns=[
    'B_HashedKey',
    'B_Geocode',
    'B_FullName',
    'B_ShortName',
    'B_Suburb',                 
    'B_PostCode',                      
    'B_State',                
    'B_Geocode',    
    'CRT_Name',
    'CRT_HashedKey',
	'CRT_AssessorName',
	'CRT_CertificateNumber',
	'CRT_UTC_IssueDate',
	'CRT_LOCAL_IssueDate',
	'CRT_UTC_CurrentTo',
	'CRT_LOCAL_CurrentTo',
	'CRT_Scope',
	'CRT_Purpose',
    'CRT_Nabers_ReferenceNumber',
	'CRT_UTC_SubmissionDate',
	'CRT_LOCAL_SubmissionDate',
	'CRT_Comment',
	'CRT_Nabers_CertifiedDate',
	'CRT_LOCAL_Nabers_CertifiedDate',
	'CRT_Nabers_CurrentTo',
	'CRT_LOCAL_Nabers_CurrentTo',
    'CRT_Nabers_OwnerName',
	'TLA_HashedKey',
    'TLA_Name',
    'TLA_AssessorName',
	'TLA_UTC_SubmittedDate',
	'TLA_LOCAL_SubmittedDate',
	'TLA_Number',
	'TLA_Status',
    'TLA_NetLettableSpace',
	'TLA_CertifiedDate',
	'TLA_LOCAL_CertifiedDate',
	'TLA_CertificateExpiry',
	'TLA_AssessmentScope',
	'FS_HashedKey',
    'FS_Name',
    'FS_Level',
	'FS_ProposedNLPD',
	'FS_UTC_ProposedCompletionDate',
	'FS_LOCAL_ProposedCompletionDate',
	'FS_ProposedReasonForAssessment',
	'FS_ProposedControlCapacity',
	'FS_CurrentNLPD',
	'FS_CurrentControlCapacity',
	'FS_PerformanceComment',
    'CRT_Nabers_RatingScope',
    'FS_NLA'])
Map_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204749 entries, 0 to 204748
# Data columns (total 11 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   B_StreetAddress                     204749 non-null  object
#  1   B_Longitude                         196305 non-null  float64
#  2   B_Latitude                          196305 non-null  float64
#  3   CRT_Nabers_StarRating               204749 non-null  float64
#  4   CRT_Nabers_RatedArea                204749 non-null  float64
#  5   CRT_Nabers_RatedHours               204749 non-null  float64
#  6   CRT_Nabers_AnnualEmissions          204749 non-null  float64
#  7   CRT_Nabers_AnnualEmissionIntensity  204749 non-null  float64
#  8   CRT_Nabers_AnnualConsumption        204749 non-null  float64
#  9   CRT_BuildingNla                     142807 non-null  float64
#  10  CRT_NumberOfLevels                  142807 non-null  float64
# dtypes: float64(10), object(1)
# memory usage: 17.2+ MB

# %%
# Filter out entries that do not have Longitude & Latitude for mapping
Map_data.dropna(subset=['B_Longitude', 'B_Latitude'], inplace=True)
#Building_df.head()
Map_data.shape
# Out:
# (196305, 11)

# %%
#Filter out buidlings and limit to Victoria 
#Map_data = Map_data[(df.B_State == "VIC")]
#Map_data.shape

# %%
Map_data_ETL = Map_data.drop_duplicates(subset=['B_StreetAddress'])
Map_data_ETL.shape
# Out:
# (2556, 11)

# %%
Map_data_ETL.to_csv('ETL_Map_data_All.csv', index=False)

# %%
import csv
import json

file = '/Users/benjaminmason/Desktop/Study/Project 03_Team 2/0_SS/ETL_Map_data_All.csv'
json_file = '/Users/benjaminmason/Desktop/Study/Project 03_Team 2/0_SS/ETL_Map_data_All.json'

#Read CSV File
def read_CSV(file, json_file):
    csv_rows = []
    with open(file) as csvfile:
        reader = csv.DictReader(csvfile)
        field = reader.fieldnames
        for row in reader:
            csv_rows.extend([{field[i]:row[field[i]] for i in range(len(field))}])
        convert_write_json(csv_rows, json_file)

#Convert csv data into json
def convert_write_json(data, json_file):
    with open(json_file, "w") as f:
        f.write(json.dumps(data, sort_keys=False, indent=4, separators=(',', ': ')))
        #f.write(json.dumps(data))
read_CSV(file,json_file)
